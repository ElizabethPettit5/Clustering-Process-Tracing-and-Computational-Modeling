# %%
import pandas as pd

# %%
df = pd.read_csv('test.txt', delimiter='	', header=1, encoding='utf-16')

# %%
df
# Out:
#              ExperimentName  Subject  Session  \
# 0    ActDynIGT2_wii(order1)        1        1
# 1    ActDynIGT2_wii(order1)        1        1
# 2    ActDynIGT2_wii(order1)        1        1
# 3    ActDynIGT2_wii(order1)        1        1
# 4    ActDynIGT2_wii(order1)        1        1
# ..                      ...      ...      ...
# 96   ActDynIGT2_wii(order1)        1        1
# 97   ActDynIGT2_wii(order1)        1        1
# 98   ActDynIGT2_wii(order1)        1        1
# 99   ActDynIGT2_wii(order1)        1        1
# 100  ActDynIGT2_wii(order1)        1        1
#
#                                      Clock.Information  Display.RefreshRate  \
# 0    <?xml version="1.0"?>\n<Clock xmlns:dt="urn:sc...               59.951
# 1    <?xml version="1.0"?>\n<Clock xmlns:dt="urn:sc...               59.951
# 2    <?xml version="1.0"?>\n<Clock xmlns:dt="urn:sc...               59.951
# 3    <?xml version="1.0"?>\n<Clock xmlns:dt="urn:sc...               59.951
# ...

# %%
df.to_excel('test2.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-59-4d257c9fc489> in <module>
# ----> 1 df.to_excel('test2.xlsx')
#
# ~/.local/share/virtualenvs/liz-wkzOJO5h/lib/python3.8/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2024             inf_rep=inf_rep,
#    2025         )
# -> 2026         formatter.write(
#    2027             excel_writer,
#    2028             sheet_name=sheet_name,
#
# ~/.local/share/virtualenvs/liz-wkzOJO5h/lib/python3.8/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     728             need_save = False
#     729         else:
# ...
